# %%
#1. Perform the following operations using R/Python on suitable data sets:
#a) read data from different formats (like csv, xls)
#b) indexing and selecting data, sort data,
#c) describe attributes of data, checking data types of each column,
#) counting unique values of data, format of each column, converting variable data type (e.g.
#from long to short, vice versa),
#e) identifying missing values and fill in the missing values

# %%
# Read Data from
import pandas as pd
df=pd.read_csv("/content/Heart.csv")
df.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
#indexing and selecting data, sort data

import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.random(20).reshape(5,4),index=["Row a","Row b","Row c","Row d","Row e"],columns=["col a","col b","col c","col d"])
df
# Out:
#           col a     col b     col c     col d
# Row a  0.980225  0.656645  0.818871  0.825177
# Row b  0.317675  0.193393  0.653222  0.390395
# Row c  0.806512  0.342959  0.671799  0.554758
# Row d  0.500332  0.447351  0.912494  0.659208
# Row e  0.710730  0.106152  0.069766  0.810260

# %%
# by using coloumn name

df[["col a","col b"]]
# Out:
#        col a     col b
# Row a      0  0.656645
# Row b      0  0.193393
# Row c      0  0.342959
# Row d      0  0.447351
# Row e      0  0.106152

# %%
# by using row index and coloumn index[.iloc]
df.iloc[3:5,2:4]
# Out:
#           col c     col d
# Row d  0.912494  0.659208
# Row e  0.069766  0.810260

# %%
df.sort_values(by=["col c"],ascending=False)
# Out:
#        col a     col b     col c     col d
# Row d      0  0.447351  0.912494  0.659208
# Row a      0  0.656645  0.818871  0.825177
# Row c      0  0.342959  0.671799  0.554758
# Row b      0  0.193393  0.653222  0.390395
# Row e      0  0.106152  0.069766  0.810260

# %%
df["col a"].dtypes
# Out:
# dtype('float64')

# %%
df.describe()
# Out:
#           col a     col b     col c     col d
# count  5.000000  5.000000  5.000000  5.000000
# mean   0.663095  0.349300  0.625231  0.647959
# std    0.259430  0.216531  0.328447  0.182277
# min    0.317675  0.106152  0.069766  0.390395
# 25%    0.500332  0.193393  0.653222  0.554758
# 50%    0.710730  0.342959  0.671799  0.659208
# 75%    0.806512  0.447351  0.818871  0.810260
# max    0.980225  0.656645  0.912494  0.825177

# %%
df['col a'].value_counts()
# Out:
# 0.980225    1
# 0.317675    1
# 0.806512    1
# 0.500332    1
# 0.710730    1
# Name: col a, dtype: int64

# %%
df.isnull()
# Out:
#        col a  col b  col c  col d
# Row a  False  False  False  False
# Row b  False  False  False  False
# Row c  False  False  False  False
# Row d  False  False  False  False
# Row e  False  False  False  False

# %%
df["col a"]=df["col a"].astype("int")
df
# Out:
#        col a     col b     col c     col d
# Row a      0  0.656645  0.818871  0.825177
# Row b      0  0.193393  0.653222  0.390395
# Row c      0  0.342959  0.671799  0.554758
# Row d      0  0.447351  0.912494  0.659208
# Row e      0  0.106152  0.069766  0.810260

# %%
df.fillna(1)
# Out:
#        col a     col b     col c     col d
# Row a      0  0.656645  0.818871  0.825177
# Row b      0  0.193393  0.653222  0.390395
# Row c      0  0.342959  0.671799  0.554758
# Row d      0  0.447351  0.912494  0.659208
# Row e      0  0.106152  0.069766  0.810260
